# %% [markdown]
# <a href="https://colab.research.google.com/github/pathakharsh123/auto-bill-master/blob/main/auto_billing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.0/883.0 kB 23.2 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fp8MexU9nDImzDsEj4Yq")
project = rf.workspace("harsh-pathak-diklc").project("edp-project")
version = project.version(14)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dependency ultralytics==8.0.196 is required but found version=8.3.7, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to edp-project-14 in yolov8:: 100%|██████████| 1388/1388 [00:00<00:00, 8116.02it/s]

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data=/content/edp-project-14/data.yaml \
epochs=80 \
imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 285MB/s]
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train2/weights/best.pt \
conf=0.55 \
source=/content/images/IMG-20240501-WA0010.jpg
# Out:
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/images/IMG-20240501-WA0010.jpg: 576x1024 1 CloseUp, 2 layss, 1 maaza, 1 maggie, 149.5ms
# Speed: 7.1ms preprocess, 149.5ms inference, 2001.6ms postprocess per image at shape (1, 3, 576, 1024)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
